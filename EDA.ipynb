# %% [markdown]
# <a href="https://colab.research.google.com/github/Amaan-Tamboli/ExploratoryDataAnalysis/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
raw_df = pd.read_csv('/content/2020 Stack Overflow Survey Responses.csv')
raw_df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 44639       45552             I am a student who is learning to code       No
# 44640       45553                     I am a developer by profession      Yes
# 44641       45555                     I am a developer by profession      Yes
# 44642       45556                     I am a developer by profession      Yes
# 44643       45557  I am not primarily a developer, but I write co...       No
#
# ...

# %%
selected_columns = [
    'Country',
    'Age',
    'Gender',
    'EdLevel',
    'UndergradMajor',
    'Hobbyist',
    'Age1stCode',
    'YearsCode',
    'YearsCodePro',
    'LanguageWorkedWith',
    'LanguageDesireNextYear',
    'NEWLearn',
    'NEWStuck',
    'Employment',
    'DevType',
    'WorkWeekHrs',
    'JobSat',
    'JobFactors',
    'NEWOvertime',
    'NEWEdImpt'
]

# %%
df = raw_df[selected_columns].copy()
df
# Out:
#                   Country   Age Gender  \
# 0                 Germany   NaN    Man
# 1          United Kingdom   NaN    NaN
# 2      Russian Federation   NaN    NaN
# 3                 Albania  25.0    Man
# 4           United States  31.0    Man
# ...                   ...   ...    ...
# 44639       United States   NaN    NaN
# 44640               Italy  39.0    Man
# 44641       United States  30.0    Man
# 44642       United States  36.0    Man
# 44643              France   NaN    NaN
#
#                                                  EdLevel  \
# 0        Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                    NaN
# 3        Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                  ...
# 44639                Associate degree (A.A., A.S., etc.)
# ...

# %%
df.shape
# Out:
# (44644, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44644 entries, 0 to 44643
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 44439 non-null  object
#  1   Age                     32788 non-null  float64
#  2   Gender                  36207 non-null  object
#  3   EdLevel                 40435 non-null  object
#  4   UndergradMajor          35998 non-null  object
#  5   Hobbyist                44613 non-null  object
#  6   Age1stCode              40806 non-null  object
#  7   YearsCode               40660 non-null  object
#  8   YearsCodePro            33192 non-null  object
#  9   LanguageWorkedWith      40482 non-null  object
#  10  LanguageDesireNextYear  38215 non-null  object
#  11  NEWLearn                39552 non-null  object
#  12  NEWStuck                39025 non-null  object
#  13  Employment              44287 non-null  object
# ...

# %%
df.Age1stCode.unique()
# Out:
# array(['13', '19', '15', '18', '16', '14', '12', '20', '42', '8', '25',
#        '22', '30', '17', '21', '10', '46', '9', '7', '11', '6', nan, '31',
#        '29', '5', 'Younger than 5 years', '28', '38', '23', '27', '41',
#        '24', '53', '26', '35', '32', '40', '33', '36', '54', '48', '56',
#        '45', '44', '34', 'Older than 85', '39', '51', '68', '50', '37',
#        '47', '43', '52', '85', '64', '55', '58', '49', '76', '72', '73',
#        '83'], dtype=object)

# %%
# errors = 'coerce' will convert any string value encountered to NaN
df['Age1stCode'] = pd.to_numeric(df['Age1stCode'], errors='coerce')
df['YearsCode'] = pd.to_numeric(df['YearsCode'], errors='coerce')
df['YearsCodePro'] = pd.to_numeric(df['YearsCodePro'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44644 entries, 0 to 44643
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 44439 non-null  object
#  1   Age                     32788 non-null  float64
#  2   Gender                  36207 non-null  object
#  3   EdLevel                 40435 non-null  object
#  4   UndergradMajor          35998 non-null  object
#  5   Hobbyist                44613 non-null  object
#  6   Age1stCode              40520 non-null  float64
#  7   YearsCode               40114 non-null  float64
#  8   YearsCodePro            31715 non-null  float64
#  9   LanguageWorkedWith      40482 non-null  object
#  10  LanguageDesireNextYear  38215 non-null  object
#  11  NEWLearn                39552 non-null  object
#  12  NEWStuck                39025 non-null  object
#  13  Employment              44287 non-null  object
# ...

# %%
df.describe()
# Out:
#                 Age   Age1stCode     YearsCode  YearsCodePro   WorkWeekHrs
# count  32788.000000  40520.00000  40114.000000  31715.000000  29830.000000
# mean      30.801867     15.38692     12.872339      8.836702     40.824544
# std        9.460777      5.06934      9.432864      7.656462     17.662098
# min        1.000000      5.00000      1.000000      1.000000      1.000000
# 25%       24.000000     12.00000      6.000000      3.000000     40.000000
# 50%       29.000000     15.00000     10.000000      6.000000     40.000000
# 75%       35.000000     18.00000     17.000000     12.000000     44.000000
# max      279.000000     85.00000     50.000000     50.000000    475.000000

# %%
df.drop(df[df['Age']<10].index, inplace=True)
df.drop(df[df['Age']>100].index, inplace=True)
df.drop(df[df['WorkWeekHrs']>140].index, inplace=True)

# %%
df['Gender'].value_counts()
# Out:
# Man                                                            33116
# Woman                                                           2545
# Non-binary, genderqueer, or gender non-conforming                259
# Man;Non-binary, genderqueer, or gender non-conforming             74
# Woman;Non-binary, genderqueer, or gender non-conforming           51
# Woman;Man                                                         51
# Woman;Man;Non-binary, genderqueer, or gender non-conforming       20
# Name: Gender, dtype: int64

# %%
import numpy as np
df.where(~(df.Gender.str.contains(';', na=False)), np.nan, inplace=True)

# %%
df['Gender'].value_counts()
# Out:
# Man                                                  33116
# Woman                                                 2545
# Non-binary, genderqueer, or gender non-conforming      259
# Name: Gender, dtype: int64

# %%
df.sample(10)
# Out:
#               Country   Age Gender  \
# 41884         Denmark  44.0    Man
# 38707  United Kingdom   NaN    NaN
# 30288           India   NaN    Man
# 16303          France  35.0    Man
# 24954           India   NaN    NaN
# 29741   United States  23.0    Man
# 35618   United States   NaN    NaN
# 29462           India  38.0    Man
# 15388        Viet Nam  33.0    Man
# 29216          Poland  56.0    Man
#
#                                                  EdLevel  \
# 41884       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 38707  Some college/university study without earning ...
# 30288    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 16303    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 24954  Some college/university study without earning ...
# 29741  Some college/university study without earning ...
# 35618                                                NaN
# 29462    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %%
df['Country'].nunique()
# Out:
# 176

# %%
top15 = df['Country'].value_counts().head(15)
top15
# Out:
# United States         8569
# India                 5875
# Germany               2812
# United Kingdom        2772
# Canada                1506
# France                1295
# Brazil                1220
# Netherlands            934
# Poland                 852
# Italy                  821
# Australia              817
# Spain                  812
# Russian Federation     771
# Sweden                 584
# Turkey                 569
# Name: Country, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(20,6))
plt.title('Top15 countries in terms of responses')
sns.barplot(x=top15.index, y=top15)

# %%
plt.figure(figsize=(15,6))
plt.title('Age of respondants')
sns.distplot(df['Age'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df['Gender'].value_counts()
# Out:
# Man                                                  33116
# Woman                                                 2545
# Non-binary, genderqueer, or gender non-conforming      259
# Name: Gender, dtype: int64

# %%
plt.figure(figsize=(15,6))
plt.title('Gender of respondants')
df['Gender'].value_counts().plot(kind='pie')

# %%
df['EdLevel'].value_counts()
# Out:
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          18618
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                        9258
# Some college/university study without earning a degree                                 5016
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     3292
# Associate degree (A.A., A.S., etc.)                                                    1285
# Other doctoral degree (Ph.D., Ed.D., etc.)                                             1147
# Primary/elementary school                                                               644
# Professional degree (JD, MD, etc.)                                                      566
# I never completed any formal education                                                  320
# Name: EdLevel, dtype: int64

# %%
plt.figure(figsize=(15,6))
plt.title('Education Level')
sns.countplot(y=df['EdLevel'])

# %%
df['UndergradMajor'].value_counts()
# Out:
# Computer science, computer engineering, or software engineering                   22402
# Another engineering discipline (such as civil, electrical, mechanical, etc.)       3313
# Information systems, information technology, or system administration              2855
# A natural science (such as biology, chemistry, physics, etc.)                      1531
# Mathematics or statistics                                                          1275
# Web development or web design                                                      1221
# A business discipline (such as accounting, finance, marketing, etc.)                883
# A humanities discipline (such as literature, history, philosophy, etc.)             667
# A social science (such as anthropology, psychology, political science, etc.)        642
# Fine arts or performing arts (such as graphic design, music, studio art, etc.)      501
# I never declared a major                                                            306
# ...

# %%
ug = (df['UndergradMajor'].value_counts()*100)/(df['UndergradMajor'].count())
plt.figure(figsize=(15,6))
sns.barplot(y=ug.index,x=ug)

# %%
df['Employment'].value_counts()
# Out:
# Employed full-time                                      31764
# Student                                                  5084
# Independent contractor, freelancer, or self-employed     3916
# Employed part-time                                       1437
# Not employed, but looking for work                       1426
# Not employed, and not looking for work                    215
# Retired                                                   147
# Name: Employment, dtype: int64

# %%
plt.figure(figsize=(15,6))
df['Employment'].value_counts().plot(kind='pie')

# %%
country_hrs = df.groupby('Country')[['WorkWeekHrs']].mean().sort_values('WorkWeekHrs',ascending=False)
country_hrs.head(15)
# Out:
#                                   WorkWeekHrs
# Country
# Lao People's Democratic Republic    72.000000
# Haiti                               60.000000
# Kuwait                              58.285714
# Iraq                                52.750000
# Afghanistan                         50.928571
# Grenada                             50.000000
# Maldives                            49.125000
# Democratic Republic of the Congo    47.500000
# Jordan                              46.375000
# United Republic of Tanzania         45.222222
# Djibouti                            45.000000
# Andorra                             45.000000
# Iran                                44.146484
# Albania                             44.041667
# Cambodia                            44.000000

# %%
df['JobSat'].value_counts()
# Out:
# Very satisfied                        10441
# Slightly satisfied                     9892
# Slightly dissatisfied                  5088
# Neither satisfied nor dissatisfied     4165
# Very dissatisfied                      2682
# Name: JobSat, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(x=df['Age'],y=df['YearsCodePro'], hue=df['JobSat'])
